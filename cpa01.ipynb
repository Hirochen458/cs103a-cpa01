# %% [markdown]
# # Life expectancy all over the world from 2000 to 2015

# %% [markdown]
# https://www.kaggle.com/kumarajarshi/life-expectancy-who
# Find the one and click that.
# The way to download it is simple. Just click the csv button on right side download area.

# %% [markdown]
# My questions are:
# 1.What is the relationship Life and GDP?
# 2.Is money means good life?

# %%
#file
import pandas as pd
lifeex_file = '/Users/hirochen/cs103a-cpa01/Life Expectancy Data.csv' 
lifeexp = pd.read_csv(lifeex_file)

# %%
#data
lifeexp.describe()
# Out:
#               Year  Life expectancy   Adult Mortality  infant deaths  \
# count  2938.000000       2928.000000      2928.000000    2938.000000
# mean   2007.518720         69.224932       164.796448      30.303948
# std       4.613841          9.523867       124.292079     117.926501
# min    2000.000000         36.300000         1.000000       0.000000
# 25%    2004.000000         63.100000        74.000000       0.000000
# 50%    2008.000000         72.100000       144.000000       3.000000
# 75%    2012.000000         75.700000       228.000000      22.000000
# max    2015.000000         89.000000       723.000000    1800.000000
#
#            Alcohol  percentage expenditure  Hepatitis B       Measles   \
# count  2744.000000             2938.000000  2385.000000    2938.000000
# mean      4.602861              738.251295    80.940461    2419.592240
# std       4.052413             1987.914858    25.070016   11467.272489
# ...

# %%
# colums
lifedf = pd.concat([lifeexp],axis = 1)
lifedf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult Mortality                  2928 non-null   float64
#  5   infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10   BMI                             2904 non-null   float64
#  11  under-five deaths                2938 non-null   int64
# ...

# %%
#subset
lifepartdf = lifedf[['Year', 'Country', 'GDP', 'Life expectancy ']]
#deathpartdf = deathdf[['Year','Country', ' BMI ']]
lifepartdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Year              2938 non-null   int64
#  1   Country           2938 non-null   object
#  2   GDP               2490 non-null   float64
#  3   Life expectancy   2928 non-null   float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 91.9+ KB

# %%
#pivot_table
import numpy as np
ratedf = pd.pivot_table(deathpartdf, index = ['Year'], aggfunc = np.sum)
ratedf.tail()
# Out:
#                GDP  Life expectancy
# Year
# 2011  1.511002e+06           12929.7
# 2012  1.598347e+06           12977.8
# 2013  1.304428e+06           13036.2
# 2014  1.552413e+06           13091.2
# 2015  1.106541e+06           13105.9

# %%
#sum of one colum
#BMidf = deathdf[[' BMI ', 'Country', 'Year']]
#BMIdf = pd.pivot_table(BMidf, index = ['Country'], aggfunc = np.sum)

#BMISum = BMIdf.sum(axis = 0).sort_values(ascending = False)
lifeSum = ratedf.sum(axis = 0).sort_values(ascending = False)
lifeSum
# Out:
# GDP                 1.863306e+07
# Life expectancy     2.026906e+05
# dtype: float64

# %%
#plot
import matplotlib.pyplot as plt
fig = plt.figure(figsize = (12, 8))
plt.plot(BMISum)
plt.xticks(range(2000, 2015, 10))
plt.legend(lifeSum)
plt.title('life with country', fontsize = 15)
plt.xlabel('GDP', fontsize = 15)
plt.ylabel(' Life exoectancy ', fontsize = 15)
plt.grid(True)
plt.show()

# %%
#groupby
deathpartdf.groupby(['Life expectancy ']).mean()
# Out:
#                          Year           GDP
# Life expectancy
# 36.3              2010.000000    662.279518
# 39.0              2000.000000    139.314773
# 41.0              2001.000000    227.779471
# 41.5              2003.000000    263.761831
# 42.3              2004.000000    263.145817
# ...                       ...           ...
# 85.0              2009.500000  20141.448753
# 86.0              2010.400000  17506.898031
# 87.0              2010.111111  23067.981729
# 88.0              2009.400000  39857.949219
# 89.0              2009.818182  24776.538663
#
# [362 rows x 2 columns]

# %% [markdown]
# In conclusion, we can found out that money can improve life expectancy. When using groupby we can see the higher GDP have higher life expectancy.
